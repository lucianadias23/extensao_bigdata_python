# %% [markdown]
# #Instalar Pandas

# %%
# !pip install pandas

# %% [markdown]
# #Importar dados do excel

# %%
import pandas as pd

# %% [markdown]
# #criar um dataframe

# %%
df = pd.read_excel( './pacientes_julho.xlsx' )

# %% [markdown]
# #exibindo quantidade de linhas e colunas

# %%
df
# Out:
#          DATA DA ADMISSÃO  NÚMERO DA ADMISSÃO TIPO DE ADMISSÃO  IDADE EM ANOS  \
# 0     2024-07-17 17:59:49              219591               PS             65
# 1     2024-07-16 13:50:51              218393               PS              2
# 2     2024-07-16 13:50:51              218393               PS              2
# 3     2024-07-16 13:50:51              218393               PS              2
# 4     2024-07-11 15:40:36              214500               PS              0
# ...                   ...                 ...              ...            ...
# 13005 2024-07-22 16:21:19              223647               PS              2
# 13006 2024-07-31 22:25:02              232261               PS              2
# 13007 2024-07-31 22:25:02              232261               PS              2
# 13008 2024-07-31 22:25:02              232261               PS              2
# 13009 2024-07-25 07:42:55              226086               PS             30
#
# ...

# %% [markdown]
# #informações gerais sobre o arquivo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13010 entries, 0 to 13009
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   DATA DA ADMISSÃO                     13010 non-null  datetime64[ns]
#  1   NÚMERO DA ADMISSÃO                   13010 non-null  int64
#  2   TIPO DE ADMISSÃO                     13010 non-null  object
#  3   IDADE EM ANOS                        13010 non-null  int64
#  4   TIPO DE TRATAMENTO                   13010 non-null  object
#  5   TIPO DE INTERNAÇÃO                   13010 non-null  object
#  6   NOME DA UNIDADE FUNCIONAL (CLÍNICA)  13010 non-null  object
#  7   ESPECIALIDADE MÉDICA                 13009 non-null  object
#  8   NOME                                 13010 non-null  object
#  9   SEXO                                 13010 non-null  object
#  10  NOME DA MÃE                          12980 non-null  object
# ...

# %% [markdown]
# #media pela idade de pacientes atendidos no mês

# %%
df['IDADE EM ANOS'].mean()
# Out:
# 12.70238278247502

# %% [markdown]
# #quais especialidades medicas receberam mais chamadas no mês

# %%
df['ESPECIALIDADE MÉDICA'].value_counts()
# Out:
# ESPECIALIDADE MÉDICA
# PEDIATRIA                    10206
# CLINICA MEDICA                1697
# CIRURGIA GERAL                 522
# ORTOPEDIA E TRAUMATOLOGIA      248
# GINECOLOGIA E OBSTETRICIA      135
# PSIQUIATRIA                     67
# BUCOMAXILOFACIAL                59
# NEONATOLOGIA                    57
# ODONTOLOGIA                     18
# Name: count, dtype: int64

# %% [markdown]
# #agrupamentos

# %%
grupos = df.groupby('ESPECIALIDADE MÉDICA')
grupos

# %%
grupos.get_group('PSIQUIATRIA')
# Out:
#          DATA DA ADMISSÃO  NÚMERO DA ADMISSÃO TIPO DE ADMISSÃO  IDADE EM ANOS  \
# 282   2024-07-16 11:54:46              218260               PS             57
# 323   2024-07-28 21:07:34              229142               PS             51
# 341   2024-07-10 14:40:20              213386               PS             22
# 634   2024-07-22 10:55:54              223204               PS             45
# 653   2024-07-10 17:30:11              213513               PS             27
# ...                   ...                 ...              ...            ...
# 11427 2024-07-02 05:25:00              205763               PS             28
# 11998 2024-07-19 08:05:59              220917               PS             27
# 12322 2024-07-03 13:49:24              207573               PS             48
# 12925 2024-07-14 20:34:01              216625               PS             65
# 12962 2024-07-29 09:32:11              229526               PS             52
#
# ...

# %%
grupo_psiquiatria = grupos.get_group('PSIQUIATRIA')

# %%
grupo_psiquiatria.to_excel('grupo_psiquiatria.xlsx', index=False)

# %% [raw]
# df = pd.read_excel('./grupo_psiquatria.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13010 entries, 0 to 13009
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   DATA DA ADMISSÃO                     13010 non-null  datetime64[ns]
#  1   NÚMERO DA ADMISSÃO                   13010 non-null  int64
#  2   TIPO DE ADMISSÃO                     13010 non-null  object
#  3   IDADE EM ANOS                        13010 non-null  int64
#  4   TIPO DE TRATAMENTO                   13010 non-null  object
#  5   TIPO DE INTERNAÇÃO                   13010 non-null  object
#  6   NOME DA UNIDADE FUNCIONAL (CLÍNICA)  13010 non-null  object
#  7   ESPECIALIDADE MÉDICA                 13009 non-null  object
#  8   NOME                                 13010 non-null  object
#  9   SEXO                                 13010 non-null  object
#  10  NOME DA MÃE                          12980 non-null  object
# ...
